# %% [markdown]
# # Analytics

# %% [markdown]
# #### Date: 2020/02
#
# #### SUMMARY:
#
# - This notebook represents the project quality analysis of the date exposed right above.

# %% [markdown]
# ### TEAM: SysArq
#
# ##### Semester: 2021/01
# ##### Professor: Hilmer Neri
#
# ##### Members:
#
# - Member x
# - Member y

# %% [markdown]
# ### LIBRARIES

# %%
# Deal with data
import pandas as pd
import numpy as np
import json

# Deal with API request
import urllib3
from urllib3 import request

# Deal with visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### GRAPH SETTINGS

# %%
# %config InlineBackend.figure_format ='retina'
sns.set(font_scale=1.5)
sns.set_style('darkgrid',
              {'xtick.bottom' : True,
               'ytick.left': True,
               'grid.linestyle':'--',
               'font.monospace': ['Computer Modern Typewriter'],
               'axes.edgecolor' : 'white'})

# %% [markdown]
# ### DATAFRAME SETTINGS

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %% [markdown]
# ### SonarCloud

# %% [markdown]
# #### KEYS

# %%
front_key = 'fga-eps-mds_2021.1-PC-GO1-Frontend'

# %%
archives_key = 'fga-eps-mds_2021.1-PC-GO1-Archives'

# %%
profile_key = 'fga-eps-mds_2021.1-PC-GO1-Profile'

# %% [markdown]
# #### METRICS

# %%
metric_list = ['files',
               'functions',
               'complexity',
               'comment_lines_density',
               'duplicated_lines_density',
               'security_rating',
               'tests',
               'test_success_density',
               'test_execution_time',
               'reliability_rating']

len(metric_list)
# Out:
# 10

# %%
def generate_metric_string(metric_list):
    metric_str = ''
    
    for metric in metric_list:
        metric_str += metric + ','
        
    return metric_str

# %%
metric_str = generate_metric_string(metric_list)

# %% [markdown]
# #### URLS

# %%
front_url = f"https://sonarcloud.io/api/measures/component_tree?component={front_key}&metricKeys={metric_str}&ps=500"
archives_url = f"https://sonarcloud.io/api/measures/component_tree?component={archives_key}&metricKeys={metric_str}&ps=500"
profile_url = f"https://sonarcloud.io/api/measures/component_tree?component={profile_key}&metricKeys={metric_str}&ps=500"

# %% [markdown]
# #### API REQUEST

# %%
http = urllib3.PoolManager()

# %%
front_request = http.request('GET', front_url)
front_request.status
# Out:
# 200

# %%
archives_request = http.request('GET', archives_url)
archives_request.status
# Out:
# 200

# %%
profile_request = http.request('GET', profile_url)
profile_request.status
# Out:
# 200

# %% [markdown]
# #### JSON DECODING

# %%
front_json = json.loads(front_request.data.decode('utf-8'))
archives_json = json.loads(archives_request.data.decode('utf-8'))
profile_json = json.loads(profile_request.data.decode('utf-8'))

# %% [markdown]
# ## DATA

# %% [markdown]
# ### PROJECT

# %%
project_front_json = front_json['baseComponent']['measures']
project_archives_json = archives_json['baseComponent']['measures']
project_profile_json = profile_json['baseComponent']['measures']

# %%
project_front_data = pd.DataFrame(project_front_json)
project_archives_data = pd.DataFrame(project_archives_json)
project_profile_data = pd.DataFrame(project_profile_json)

# %% [markdown]
# ##### FRONT

# %%
project_front_data
# Out:
#   bestValue                    metric value
# 0     False  duplicated_lines_density   1.8
# 1       NaN                 functions   556
# 2      True           security_rating   1.0
# 3       NaN                     files   102
# 4       NaN                complexity   759
# 5      True        reliability_rating   1.0
# 6     False     comment_lines_density   0.8

# %% [markdown]
# ##### ARCHIVES

# %%
project_archives_data
# Out:
#   bestValue                    metric value
# 0      True  duplicated_lines_density   0.0
# 1       NaN                 functions    44
# 2      True           security_rating   1.0
# 3       NaN                     files    21
# 4       NaN                complexity    66
# 5      True        reliability_rating   1.0
# 6     False     comment_lines_density   6.7

# %% [markdown]
# #### PROFILE

# %%
project_profile_data
# Out:
#   bestValue                    metric value
# 0      True  duplicated_lines_density   0.0
# 1       NaN                 functions     5
# 2      True           security_rating   1.0
# 3       NaN                     files    17
# 4       NaN                complexity     8
# 5      True        reliability_rating   1.0
# 6     False     comment_lines_density  16.7

# %% [markdown]
# ### FILES

# %%
def metric_per_file(json):
    file_json = []
    
    for component in json['components']:
        if component['qualifier'] == 'FIL':
            file_json.append(component)
            
    return file_json

# %%
front_file_json = metric_per_file(front_json)
archives_file_json = metric_per_file(archives_json)
profile_file_json = metric_per_file(profile_json)

# %%
def generate_file_dataframe(metric_list, json, language_extension):
    df_columns = metric_list
    df = pd.DataFrame(columns = df_columns, dtype=object)
    
    for file in json:
        try:
            if file['language'] == language_extension:
                for measure in file['measures']:
                    df.at[file['path'], measure['metric']] = measure['value']
        except:
            pass
        
    df.reset_index(inplace = True)
    df = df.rename({'index': 'path'}, axis=1).drop(['files'], axis=1)

    return df

# %%
front_files_data = generate_file_dataframe(metric_list, front_file_json, language_extension = 'js')
archives_files_data = generate_file_dataframe(metric_list, archives_file_json, language_extension = 'py')
profile_files_data = generate_file_dataframe(metric_list, profile_file_json, language_extension = 'py')

# %% [markdown]
# ##### FRONT

# %%
front_files_data
# Out:
#                                                  path functions complexity  \
# 0   sysarq/src/tests/Documents/Create/ConnectionEr...         5          5
# 1   sysarq/src/pages/components/Inputs/Abbreviatio...         9          9
# 2                                   sysarq/src/Api.js         0          0
# 3                                   sysarq/src/App.js         1          1
# 4                        sysarq/src/tests/App.test.js         2          2
# 5   sysarq/src/pages/FieldsRegister/BoxAbbreviatio...         1          1
# 6            sysarq/src/tests/BoxAbbreviation.test.js         2          2
# 7   sysarq/src/pages/components/Container/ChipsCon...         2          2
# 8   sysarq/src/pages/components/CommonSet/CommonSe...         1          1
# 9   sysarq/src/pages/Documents/Create/CreateAdmini...        37         61
# 10  sysarq/src/tests/Documents/Create/CreateAdmini...         5          5
# 11  sysarq/src/pages/Documents/Create/CreateArchiv...        40         65
# 12  sysarq/src/tests/Documents/Create/CreateArchiv...         7          7
# 13  sysarq/src/pages/FieldsRegister/CreateBoxAbbre...        17         18
# 14     sysarq/src/tests/CreateBoxAbbreviation.test.js         9         11
# 15  sysarq/src/pages/FieldsRegister/CreateDocument...        14         14
# 16     sysarq/src/tests/CreateDocumentSubject.test.js        10         12
# 17  sysarq/src/pages/FieldsRegister/CreateDocument...        14         14
# 18        sysarq/src/tests/CreateDocumentType.test.js        10         12
# 19  sysarq/src/pages/Documents/Create/CreateFreque...        14         20
# 20  sysarq/src/tests/Documents/Create/CreateFreque...         7          7
# 21  sysarq/src/pages/Documents/Create/CreateFreque...        16         24
# 22  sysarq/src/tests/Documents/Create/CreateFreque...         7          7
# 23     sysarq/src/pages/FieldsRegister/CreateShelf.js        18         26
# 24               sysarq/src/tests/CreateShelf.test.js        18         21
# 25     sysarq/src/pages/FieldsRegister/CreateUnity.js        26         26
# 26               sysarq/src/tests/CreateUnity.test.js         8         10
# 27                 sysarq/src/tests/DataTable.test.js        20         22
# 28  sysarq/src/tests/ConnectionErrors/DataTableCon...         5          5
# 29       sysarq/src/tests/Documents/Documents.test.js         2          2
# 30  sysarq/src/pages/components/Container/Document...         2          2
# 31  sysarq/src/pages/components/Actions/DocumentsC...         2          3
# 32  sysarq/src/pages/FieldsRegister/DocumentSubjec...         1          1
# 33           sysarq/src/tests/DocumentSubject.test.js         2          2
# 34  sysarq/src/tests/Documents/Create/ConnectionEr...         5          5
# 35    sysarq/src/pages/FieldsRegister/DocumentType.js         1          1
# 36              sysarq/src/tests/DocumentType.test.js         2          2
# 37  sysarq/src/tests/Documents/Create/ConnectionEr...         5          5
# 38  sysarq/src/pages/components/Inputs/DocumentTyp...         9         10
# 39  sysarq/src/pages/FieldsRegister/FieldsRegister.js         2          2
# 40            sysarq/src/tests/FieldsRegister.test.js         3          3
# 41            sysarq/src/pages/FieldsRegister/form.js         3          9
# 42      sysarq/src/pages/FieldsRegister/FrontCover.js         1          1
# 43                sysarq/src/tests/FrontCover.test.js         2          2
# 44                           sysarq/src/pages/Home.js         1          1
# 45                                sysarq/src/index.js         0          0
# 46                  sysarq/src/tests/support/index.js         7          7
# 47     sysarq/src/pages/components/DataTable/index.js        25         45
# 48  sysarq/src/pages/components/SpecialLabels/inde...         2          2
# 49  sysarq/src/pages/components/MenuCard/Documents...         3          6
# 50  sysarq/src/pages/components/MenuCard/Fields/in...         3          8
# 51        sysarq/src/pages/components/Footer/index.js         1          1
# 52       sysarq/src/pages/components/AddChip/index.js         1          1
# 53    sysarq/src/pages/components/PopUpAlert/index.js         1          2
# 54        sysarq/src/pages/components/Header/index.js         2          4
# 55                sysarq/src/pages/Documents/index.js         1          1
# 56                    sysarq/src/pages/Login/index.js         9         16
# 57                     sysarq/src/tests/index.test.js         2          2
# 58                 sysarq/src/tests/inputTest.test.js         5          6
# 59                     sysarq/src/tests/Login.test.js        13         15
# 60                  sysarq/src/tests/MenuCard.test.js         5          5
# 61   sysarq/src/pages/components/Inputs/NotesInput.js         2          2
# 62  sysarq/src/pages/components/Inputs/NumberInput.js         2          2
# 63  sysarq/src/pages/components/Inputs/NumberProce...         2          2
# 64                  sysarq/src/Routes/privateRoute.js         1          2
# 65  sysarq/src/tests/Documents/Create/ConnectionEr...         5          5
# 66    sysarq/src/pages/components/Inputs/RackInput.js         9          9
# 67  sysarq/src/pages/components/Inputs/ReceivedDat...         2          2
# 68  sysarq/src/pages/components/Inputs/ReferencePe...         9         12
# 69                      sysarq/src/reportWebVitals.js         2          4
# 70                         sysarq/src/pages/Search.js         7         11
# 71                    sysarq/src/tests/Search.test.js        11         11
# 72                     sysarq/src/pages/SearchList.js         1          1
# 73                sysarq/src/tests/SearchList.test.js         2          2
# 74  sysarq/src/pages/components/Inputs/SenderUnitI...         4          5
# 75                 sysarq/src/tests/support/server.js        16         57
# 76                           sysarq/src/setupTests.js         0          0
# 77           sysarq/src/pages/FieldsRegister/Shelf.js         1          1
# 78                     sysarq/src/tests/Shelf.test.js         2          2
# 79  sysarq/src/tests/Documents/Create/ConnectionEr...         5          5
# 80   sysarq/src/pages/components/Inputs/ShelfInput.js         9          9
# 81                              sysarq/src/support.js         4         10
# 82  sysarq/src/pages/components/DataTable/tablesHe...         2         11
# 83  sysarq/src/tests/Documents/Create/ConnectionEr...         7          7
# 84           sysarq/src/pages/FieldsRegister/Unity.js         1          1
# 85                     sysarq/src/tests/Unity.test.js         2          2
#
#    comment_lines_density duplicated_lines_density security_rating tests  \
# 0                    0.0                      0.0             1.0   NaN
# 1                    0.0                      0.0             1.0   NaN
# 2                    0.0                      0.0             1.0   NaN
# 3                    0.0                      0.0             1.0   NaN
# 4                    0.0                      0.0             1.0   NaN
# 5                    0.0                      0.0             1.0   NaN
# 6                    0.0                      0.0             1.0   NaN
# 7                    0.0                      0.0             1.0   NaN
# 8                    0.0                      0.0             1.0   NaN
# 9                    0.0                      0.0             1.0   NaN
# 10                   0.0                      0.0             1.0   NaN
# 11                   3.5                      7.8             1.0   NaN
# 12                   0.0                      0.0             1.0   NaN
# 13                   0.0                      0.0             1.0   NaN
# 14                   0.0                      0.0             1.0   NaN
# 15                   0.0                      0.0             1.0   NaN
# 16                   0.0                      0.0             1.0   NaN
# 17                   0.0                      0.0             1.0   NaN
# 18                   0.0                      0.0             1.0   NaN
# 19                   0.0                     25.4             1.0   NaN
# 20                   2.0                      0.0             1.0   NaN
# 21                   0.0                      0.0             1.0   NaN
# 22                   0.0                      0.0             1.0   NaN
# 23                   0.0                      6.8             1.0   NaN
# 24                   0.0                      0.0             1.0   NaN
# 25                   0.0                      0.0             1.0   NaN
# 26                   0.0                      0.0             1.0   NaN
# 27                   0.0                      0.0             1.0   NaN
# 28                   0.0                      0.0             1.0   NaN
# 29                   0.0                      0.0             1.0   NaN
# 30                   1.3                      0.0             1.0   NaN
# 31                   0.0                      0.0             1.0   NaN
# 32                   0.0                      0.0             1.0   NaN
# 33                   0.0                      0.0             1.0   NaN
# 34                   0.0                      0.0             1.0   NaN
# 35                   0.0                      0.0             1.0   NaN
# 36                   0.0                      0.0             1.0   NaN
# 37                   0.0                      0.0             1.0   NaN
# 38                   0.0                      0.0             1.0   NaN
# 39                   0.0                      0.0             1.0   NaN
# 40                   0.0                      0.0             1.0   NaN
# 41                   0.0                     21.5             1.0   NaN
# 42                   0.0                      0.0             1.0   NaN
# 43                   0.0                      0.0             1.0   NaN
# 44                   0.0                      0.0             1.0   NaN
# 45                  27.3                      0.0             1.0   NaN
# 46                   0.0                      0.0             1.0   NaN
# 47                   0.0                      0.0             1.0   NaN
# 48                   0.0                      0.0             1.0   NaN
# 49                   1.9                      0.0             1.0   NaN
# 50                   0.0                      0.0             1.0   NaN
# 51                   0.0                      0.0             1.0   NaN
# 52                   0.0                      0.0             1.0   NaN
# 53                   0.0                      0.0             1.0   NaN
# 54                   0.0                      0.0             1.0   NaN
# 55                   3.6                      0.0             1.0   NaN
# 56                   0.0                      0.0             1.0   NaN
# 57                   0.0                      0.0             1.0   NaN
# 58                   0.0                      0.0             1.0   NaN
# 59                   0.0                      0.0             1.0   NaN
# 60                   0.0                      0.0             1.0   NaN
# 61                   0.0                      0.0             1.0   NaN
# 62                   0.0                      0.0             1.0   NaN
# 63                   0.0                      0.0             1.0   NaN
# 64                   0.0                      0.0             1.0   NaN
# 65                   0.0                      0.0             1.0   NaN
# 66                   0.0                      0.0             1.0   NaN
# 67                   0.0                      0.0             1.0   NaN
# 68                   0.0                      0.0             1.0   NaN
# 69                   0.0                      0.0             1.0   NaN
# 70                   0.0                      0.0             1.0   NaN
# 71                   1.4                      0.0             1.0   NaN
# 72                   0.0                      0.0             1.0   NaN
# 73                   0.0                      0.0             1.0   NaN
# 74                   0.0                      0.0             1.0   NaN
# 75                   0.0                      0.0             1.0   NaN
# 76                   0.0                      0.0             1.0   NaN
# 77                   0.0                      0.0             1.0   NaN
# 78                   0.0                      0.0             1.0   NaN
# 79                   0.0                      0.0             1.0   NaN
# 80                   0.0                      0.0             1.0   NaN
# 81                   0.0                      0.0             1.0   NaN
# 82                   0.0                      0.0             1.0   NaN
# 83                   0.0                      0.0             1.0   NaN
# 84                   0.0                      0.0             1.0   NaN
# 85                   0.0                      0.0             1.0   NaN
#
#    test_success_density test_execution_time reliability_rating
# 0                 100.0                 NaN                1.0
# 1                 100.0                 NaN                1.0
# 2                 100.0                 NaN                1.0
# 3                 100.0                 NaN                1.0
# 4                 100.0                 NaN                1.0
# 5                 100.0                 NaN                1.0
# 6                 100.0                 NaN                1.0
# 7                 100.0                 NaN                1.0
# 8                 100.0                 NaN                1.0
# 9                 100.0                 NaN                1.0
# 10                100.0                 NaN                1.0
# 11                100.0                 NaN                1.0
# 12                100.0                 NaN                1.0
# 13                100.0                 NaN                1.0
# 14                100.0                 NaN                1.0
# 15                100.0                 NaN                1.0
# 16                100.0                 NaN                1.0
# 17                100.0                 NaN                1.0
# 18                100.0                 NaN                1.0
# 19                100.0                 NaN                1.0
# 20                100.0                 NaN                1.0
# 21                100.0                 NaN                1.0
# 22                100.0                 NaN                1.0
# 23                100.0                 NaN                1.0
# 24                100.0                 NaN                1.0
# 25                100.0                 NaN                1.0
# 26                100.0                 NaN                1.0
# 27                100.0                 NaN                1.0
# 28                100.0                 NaN                1.0
# 29                100.0                 NaN                1.0
# 30                100.0                 NaN                1.0
# 31                100.0                 NaN                1.0
# 32                100.0                 NaN                1.0
# 33                100.0                 NaN                1.0
# 34                100.0                 NaN                1.0
# 35                100.0                 NaN                1.0
# 36                100.0                 NaN                1.0
# 37                100.0                 NaN                1.0
# 38                100.0                 NaN                1.0
# 39                100.0                 NaN                1.0
# 40                100.0                 NaN                1.0
# 41                100.0                 NaN                1.0
# 42                100.0                 NaN                1.0
# 43                100.0                 NaN                1.0
# 44                100.0                 NaN                1.0
# 45                100.0                 NaN                1.0
# 46                100.0                 NaN                1.0
# 47                100.0                 NaN                1.0
# 48                100.0                 NaN                1.0
# 49                100.0                 NaN                1.0
# 50                100.0                 NaN                1.0
# 51                100.0                 NaN                1.0
# 52                100.0                 NaN                1.0
# 53                100.0                 NaN                1.0
# 54                100.0                 NaN                1.0
# 55                100.0                 NaN                1.0
# 56                100.0                 NaN                1.0
# 57                100.0                 NaN                1.0
# 58                100.0                 NaN                1.0
# 59                100.0                 NaN                1.0
# 60                100.0                 NaN                1.0
# 61                100.0                 NaN                1.0
# 62                100.0                 NaN                1.0
# 63                100.0                 NaN                1.0
# 64                100.0                 NaN                1.0
# 65                100.0                 NaN                1.0
# 66                100.0                 NaN                1.0
# 67                100.0                 NaN                1.0
# 68                100.0                 NaN                1.0
# 69                100.0                 NaN                1.0
# 70                100.0                 NaN                1.0
# 71                100.0                 NaN                1.0
# 72                100.0                 NaN                1.0
# 73                100.0                 NaN                1.0
# 74                100.0                 NaN                1.0
# 75                100.0                 NaN                1.0
# 76                100.0                 NaN                1.0
# 77                100.0                 NaN                1.0
# 78                100.0                 NaN                1.0
# 79                100.0                 NaN                1.0
# 80                100.0                 NaN                1.0
# 81                100.0                 NaN                1.0
# 82                100.0                 NaN                1.0
# 83                100.0                 NaN                1.0
# 84                100.0                 NaN                1.0
# 85                100.0                 NaN                1.0

# %% [markdown]
# ##### ARCHIVES

# %%
archives_files_data
# Out:
#                                        path functions complexity  \
# 0   archives_app/migrations/0001_initial.py         0          0
# 1                  archives_app/__init__.py         0          0
# 2       archives_app/migrations/__init__.py         0          0
# 3                       project/__init__.py         0          0
# 4                     archives_app/admin.py         0          0
# 5                      archives_app/apps.py         0          0
# 6                           project/asgi.py         0          0
# 7          archives_app/documents_models.py         0          0
# 8     archives_app/documents_serializers.py         3          6
# 9             archives_app/fields_models.py         0          0
# 10       archives_app/fields_serializers.py         0          0
# 11                                manage.py         1          2
# 12               archives_app/middleware.py         3          4
# 13                tests/middleware_tests.py         2          2
# 14                      project/settings.py         0          0
# 15                          project/urls.py         0          0
# 16                      tests/urls_tests.py        31         32
# 17                    archives_app/views.py         4         20
# 18                          project/wsgi.py         0          0
#
#    comment_lines_density duplicated_lines_density security_rating tests  \
# 0                    0.6                      0.0             1.0   NaN
# 1                    NaN                      0.0             1.0   NaN
# 2                    NaN                      0.0             1.0   NaN
# 3                    NaN                      0.0             1.0   NaN
# 4                    NaN                      0.0             1.0   NaN
# 5                    0.0                      0.0             1.0   NaN
# 6                   66.7                      0.0             1.0   NaN
# 7                    0.0                      0.0             1.0   NaN
# 8                    0.0                      0.0             1.0   NaN
# 9                    0.0                      0.0             1.0   NaN
# 10                   0.0                      0.0             1.0   NaN
# 11                  16.7                      0.0             1.0   NaN
# 12                  20.8                      0.0             1.0   NaN
# 13                   0.0                      0.0             1.0   NaN
# 14                  25.7                      0.0             1.0   NaN
# 15                  12.5                      0.0             1.0   NaN
# 16                   0.0                      0.0             1.0   NaN
# 17                  16.9                      0.0             1.0   NaN
# 18                  66.7                      0.0             1.0   NaN
#
#    test_success_density test_execution_time reliability_rating
# 0                 100.0                 NaN                1.0
# 1                 100.0                 NaN                1.0
# 2                 100.0                 NaN                1.0
# 3                 100.0                 NaN                1.0
# 4                 100.0                 NaN                1.0
# 5                 100.0                 NaN                1.0
# 6                 100.0                 NaN                1.0
# 7                 100.0                 NaN                1.0
# 8                 100.0                 NaN                1.0
# 9                 100.0                 NaN                1.0
# 10                100.0                 NaN                1.0
# 11                100.0                 NaN                1.0
# 12                100.0                 NaN                1.0
# 13                100.0                 NaN                1.0
# 14                100.0                 NaN                1.0
# 15                100.0                 NaN                1.0
# 16                100.0                 NaN                1.0
# 17                100.0                 NaN                1.0
# 18                100.0                 NaN                1.0

# %% [markdown]
# ##### PROFILE

# %%
profile_files_data
# Out:
#                                       path functions complexity  \
# 0   profile_app/migrations/0001_initial.py         0          0
# 1                  profile_app/__init__.py         0          0
# 2       profile_app/migrations/__init__.py         0          0
# 3                      project/__init__.py         0          0
# 4                     profile_app/admin.py         0          0
# 5                      profile_app/apps.py         0          0
# 6                          project/asgi.py         0          0
# 7                                manage.py         1          2
# 8                    profile_app/models.py         2          3
# 9               profile_app/serializers.py         1          2
# 10                     project/settings.py         0          0
# 11                         project/urls.py         0          0
# 12                     tests/urls_tests.py         1          1
# 13                    profile_app/views.py         0          0
# 14                         project/wsgi.py         0          0
#
#    comment_lines_density duplicated_lines_density security_rating tests  \
# 0                    3.7                      0.0             1.0   NaN
# 1                    NaN                      0.0             1.0   NaN
# 2                    NaN                      0.0             1.0   NaN
# 3                    NaN                      0.0             1.0   NaN
# 4                    NaN                      0.0             1.0   NaN
# 5                    0.0                      0.0             1.0   NaN
# 6                   66.7                      0.0             1.0   NaN
# 7                   16.7                      0.0             1.0   NaN
# 8                    0.0                      0.0             1.0   NaN
# 9                    0.0                      0.0             1.0   NaN
# 10                  21.1                      0.0             1.0   NaN
# 11                  11.1                      0.0             1.0   NaN
# 12                   0.0                      0.0             1.0   NaN
# 13                   0.0                      0.0             1.0   NaN
# 14                  66.7                      0.0             1.0   NaN
#
#    test_success_density test_execution_time reliability_rating
# 0                 100.0                 NaN                1.0
# 1                 100.0                 NaN                1.0
# 2                 100.0                 NaN                1.0
# 3                 100.0                 NaN                1.0
# 4                 100.0                 NaN                1.0
# 5                 100.0                 NaN                1.0
# 6                 100.0                 NaN                1.0
# 7                 100.0                 NaN                1.0
# 8                 100.0                 NaN                1.0
# 9                 100.0                 NaN                1.0
# 10                100.0                 NaN                1.0
# 11                100.0                 NaN                1.0
# 12                100.0                 NaN                1.0
# 13                100.0                 NaN                1.0
# 14                100.0                 NaN                1.0

# %% [markdown]
# # ANALYSIS

# %% [markdown]
# ## MAINTAINABILITY

# %% [markdown]
# ### CODE QUALITY

# %% [markdown]
# ##### COMPLEXITY

# %%
def m1(df):
    
    density_non_complex_files = round((len(df[(df['complexity'].astype(float)/df['functions'].astype(float)) < 10])/len(df))*100, 2)
    
    return density_non_complex_files

# %% [markdown]
# ##### COMMENTS

# %%
def m2(df):
    
    density_comment_files = round((len(df[(df['comment_lines_density'].astype(float) > 10) & (df['comment_lines_density'].astype(float) < 30)])/len(df))*100, 2)
    
    return density_comment_files

# %% [markdown]
# ##### DUPLICATIONS

# %%
def m3(df):
    
    duplication = round((len(df[(df['duplicated_lines_density'].astype(float) < 5)])/len(df))*100, 2)
    
    return duplication

# %% [markdown]
# ### BLOCKING CODE

# %% [markdown]
# #### NON-BLOCKING FILES

# %%
def m4(df):
    
    non_blocking_files = round((len(df[(df['security_rating'].astype(float) >= 4)])/len(df))*100,2)
    
    return non_blocking_files

# %% [markdown]
# ## RELIABILITY

# %% [markdown]
# #### TEST SUCCESS

# %%
def m5(df):
    
    test_success_file = df[['path', 'test_success_density']]
    test_success_repository = df['test_success_density'].astype(float).mean()
    
    print("Project test unit density: ", test_success_repository)
    
    return test_success_file

# %% [markdown]
# #### FAST TESTS

# %%
def m6(df):
    
    fast_test_df = df[(df['test_execution_time'].astype(float) < 300)]
    fast_test_df['fast_test'] = fast_test_df['test_execution_time']/fast_test_df['tests']
    
    fast_test_file = fast_test_df[['path', 'fast_test']]
    
    fast_test_repository = fast_test_df['fast_test'].astype(float).mean()
    
    print("Project test unit density: ", fast_test_repository)
    
    return fast_test_file

# %% [markdown]
# ## PRODUCTIVITY

# %% [markdown]
# #### RESOLVED ISSUES' THROUGHPUT

# %%
def m7(number_of_issues_resolved, number_of_issues):
    
    resolved_issues_throughput = round((number_of_issues_resolved / number_of_issues) * 100, 2)
    
    return resolved_issues_throughput

# %% [markdown]
# #### ISSUE TYPE IN A TIMEFRAME

# %%
def density(issue, number_of_issues):
    issue_density = round((issue / number_of_issues) * 100, 2)
    return issue_density

# %%
def m8(tag_dict, number_of_issues):
    
    issue_densities = {
        "hotfix": [density(tag_dict["HOTFIX"], number_of_issues)],
        "docs": [density(tag_dict["DOCS"], number_of_issues)],
        "feature": [density(tag_dict["FEATURE"], number_of_issues)],
        "arq": [density(tag_dict["ARQ"], number_of_issues)],
        "devops": [density(tag_dict["DEVOPS"], number_of_issues)],
        "analytics": [density(tag_dict["ANALYTICS"], number_of_issues)],
        "us": [density(tag_dict["US"], number_of_issues)],
        "easy": [density(tag_dict["EASY"], number_of_issues)],
        "medium": [density(tag_dict["MEDIUM"], number_of_issues)],
        "hard": [density(tag_dict["HARD"], number_of_issues)],
        "eps": [density(tag_dict["EPS"], number_of_issues)],
        "mds": [density(tag_dict["MDS"], number_of_issues)]
    }

    issue_densities = pd.DataFrame.from_dict(issue_densities).T.reset_index()
    
    issue_densities.columns = ['density' ,'percentage']
    
    return issue_densities

# %% [markdown]
# #### BUGS RATIO

# %%
def m9(tag_dict, number_of_issues):
    
    bugs_ratio = round(((tag_dict["DOCS"] + tag_dict["FEATURE"] + tag_dict["ARQ"] + tag_dict["DEVOPS"] + tag_dict["ANALYTICS"]) / number_of_issues) * 100, 2)
    
    return bugs_ratio

# %% [markdown]
# ### PRODUCTIVITY METRIC RESULTS PER SPRINT

# %% [markdown]
# #### PRE-SPRINT AND SPRINT 1

# %%
NUMBER_OF_ISSUES_RESOLVED = 10
NUMBER_OF_ISSUES = 10

TAGS = {
    "HOTFIX": 0,
    "DOCS": 7,
    "FEATURE": 0,
    "ARQ": 0,
    "DEVOPS": 4,
    "ANALYTICS": 0,
    "US": 0,
    "EASY": 4,
    "MEDIUM": 2,
    "HARD": 4,
    "EPS": 8,
    "MDS": 3
}

# %%
pre_sprint_m7 = m7(NUMBER_OF_ISSUES_RESOLVED, NUMBER_OF_ISSUES)
pre_sprint_m7
# Out:
# 100.0

# %%
pre_sprint_m8 = m8(TAGS, NUMBER_OF_ISSUES)
pre_sprint_m8
# Out:
#       density  percentage
# 0      hotfix         0.0
# 1        docs        70.0
# 2     feature         0.0
# 3         arq         0.0
# 4      devops        40.0
# 5   analytics         0.0
# 6          us         0.0
# 7        easy        40.0
# 8      medium        20.0
# 9        hard        40.0
# 10        eps        80.0
# 11        mds        30.0

# %%
pre_sprint_m9 = m9(TAGS, NUMBER_OF_ISSUES)
pre_sprint_m9
# Out:
# 110.0

# %% [markdown]
# #### SPRINT 2

# %%
NUMBER_OF_ISSUES_RESOLVED = 7
NUMBER_OF_ISSUES = 11

TAGS = {
    "HOTFIX": 0,
    "DOCS": 5,
    "FEATURE": 2,
    "ARQ": 1,
    "DEVOPS": 1,
    "ANALYTICS": 0,
    "US": 2,
    "EASY": 3,
    "MEDIUM": 6,
    "HARD": 2,
    "EPS": 7,
    "MDS": 3
}

# %%
s2_m7 = m7(NUMBER_OF_ISSUES_RESOLVED, NUMBER_OF_ISSUES)
s2_m7
# Out:
# 63.64

# %%
s2_m8 = m8(TAGS, NUMBER_OF_ISSUES)
s2_m8
# Out:
#       density  percentage
# 0      hotfix        0.00
# 1        docs       45.45
# 2     feature       18.18
# 3         arq        9.09
# 4      devops        9.09
# 5   analytics        0.00
# 6          us       18.18
# 7        easy       27.27
# 8      medium       54.55
# 9        hard       18.18
# 10        eps       63.64
# 11        mds       27.27

# %%
s2_m9 = m9(TAGS, NUMBER_OF_ISSUES)
s2_m9
# Out:
# 81.82

# %% [markdown]
# #### SPRINT 3

# %%
NUMBER_OF_ISSUES_RESOLVED = 12
NUMBER_OF_ISSUES = 15

TAGS = {
    "HOTFIX": 0,
    "DOCS": 10,
    "FEATURE": 2,
    "ARQ": 2,
    "DEVOPS": 1,
    "ANALYTICS": 0,
    "US": 2,
    "EASY": 3,
    "MEDIUM": 8,
    "HARD": 4,
    "EPS": 11,
    "MDS": 4
}

# %%
s3_m7 = m7(NUMBER_OF_ISSUES_RESOLVED, NUMBER_OF_ISSUES)
s3_m7
# Out:
# 80.0

# %%
s3_m8 = m8(TAGS, NUMBER_OF_ISSUES)
s3_m8
# Out:
#       density  percentage
# 0      hotfix        0.00
# 1        docs       66.67
# 2     feature       13.33
# 3         arq       13.33
# 4      devops        6.67
# 5   analytics        0.00
# 6          us       13.33
# 7        easy       20.00
# 8      medium       53.33
# 9        hard       26.67
# 10        eps       73.33
# 11        mds       26.67

# %%
s3_m9 = m9(TAGS, NUMBER_OF_ISSUES)
s3_m9
# Out:
# 100.0

# %% [markdown]
# #### SPRINT 4

# %%
NUMBER_OF_ISSUES_RESOLVED = 6
NUMBER_OF_ISSUES = 12

TAGS = {
    "HOTFIX": 0,
    "DOCS": 4,
    "FEATURE": 5,
    "ARQ": 1,
    "DEVOPS": 3,
    "ANALYTICS": 0,
    "US": 5,
    "EASY": 3,
    "MEDIUM": 5,
    "HARD": 4,
    "EPS": 9,
    "MDS": 4
}

# %%
s4_m7 = m7(NUMBER_OF_ISSUES_RESOLVED, NUMBER_OF_ISSUES)
s4_m7
# Out:
# 50.0

# %%
s4_m8 = m8(TAGS, NUMBER_OF_ISSUES)
s4_m8
# Out:
#       density  percentage
# 0      hotfix        0.00
# 1        docs       33.33
# 2     feature       41.67
# 3         arq        8.33
# 4      devops       25.00
# 5   analytics        0.00
# 6          us       41.67
# 7        easy       25.00
# 8      medium       41.67
# 9        hard       33.33
# 10        eps       75.00
# 11        mds       33.33

# %%
s4_m9 = m9(TAGS, NUMBER_OF_ISSUES)
s4_m9
# Out:
# 108.33

# %% [markdown]
# #### SPRINT 5

# %%
NUMBER_OF_ISSUES_RESOLVED = 2
NUMBER_OF_ISSUES = 11

TAGS = {
    "HOTFIX": 1,
    "DOCS": 2,
    "FEATURE": 6,
    "ARQ": 1,
    "DEVOPS": 2,
    "ANALYTICS": 0,
    "US": 7,
    "EASY": 1,
    "MEDIUM": 7,
    "HARD": 3,
    "EPS": 7,
    "MDS": 5
}

# %%
s5_m7 = m7(NUMBER_OF_ISSUES_RESOLVED, NUMBER_OF_ISSUES)
s5_m7
# Out:
# 18.18

# %%
s5_m8 = m8(TAGS, NUMBER_OF_ISSUES)
s5_m8
# Out:
#       density  percentage
# 0      hotfix        9.09
# 1        docs       18.18
# 2     feature       54.55
# 3         arq        9.09
# 4      devops       18.18
# 5   analytics        0.00
# 6          us       63.64
# 7        easy        9.09
# 8      medium       63.64
# 9        hard       27.27
# 10        eps       63.64
# 11        mds       45.45

# %%
s5_m9 = m9(TAGS, NUMBER_OF_ISSUES)
s5_m9
# Out:
# 100.0

# %% [markdown]
# #### SPRINT 6

# %%
NUMBER_OF_ISSUES_RESOLVED = 13
NUMBER_OF_ISSUES = 15

TAGS = {
    "HOTFIX": 4,
    "DOCS": 1,
    "FEATURE": 6,
    "ARQ": 0,
    "DEVOPS": 3,
    "ANALYTICS": 0,
    "US": 7,
    "EASY": 3,
    "MEDIUM": 7,
    "HARD": 3,
    "EPS": 11,
    "MDS": 4
}

# %%
s6_m7 = m7(NUMBER_OF_ISSUES_RESOLVED, NUMBER_OF_ISSUES)
s6_m7
# Out:
# 86.67

# %%
s6_m8 = m8(TAGS, NUMBER_OF_ISSUES)
s6_m8
# Out:
#       density  percentage
# 0      hotfix       26.67
# 1        docs        6.67
# 2     feature       40.00
# 3         arq        0.00
# 4      devops       20.00
# 5   analytics        0.00
# 6          us       46.67
# 7        easy       20.00
# 8      medium       46.67
# 9        hard       20.00
# 10        eps       73.33
# 11        mds       26.67

# %%
s6_m9 = m9(TAGS, NUMBER_OF_ISSUES)
s6_m9
# Out:
# 66.67

# %% [markdown]
# #### SPRINT 7

# %%
NUMBER_OF_ISSUES_RESOLVED = 6
NUMBER_OF_ISSUES = 9

TAGS = {
    "HOTFIX": 0,
    "DOCS": 5,
    "FEATURE": 2,
    "ARQ": 1,
    "DEVOPS": 1,
    "ANALYTICS": 1,
    "US": 2,
    "EASY": 2,
    "MEDIUM": 6,
    "HARD": 1,
    "EPS": 8,
    "MDS": 1
}

# %%
s7_m7 = m7(NUMBER_OF_ISSUES_RESOLVED, NUMBER_OF_ISSUES)
s7_m7
# Out:
# 66.67

# %%
s7_m8 = m8(TAGS, NUMBER_OF_ISSUES)
s7_m8
# Out:
#       density  percentage
# 0      hotfix        0.00
# 1        docs       55.56
# 2     feature       22.22
# 3         arq       11.11
# 4      devops       11.11
# 5   analytics       11.11
# 6          us       22.22
# 7        easy       22.22
# 8      medium       66.67
# 9        hard       11.11
# 10        eps       88.89
# 11        mds       11.11

# %%
s7_m9 = m9(TAGS, NUMBER_OF_ISSUES)
s7_m9
# Out:
# 111.11

# %% [markdown]
# ### CODE METRIC RESULTS

# %% [markdown]
# #### FRONTEND

# %%
m1(front_files_data)
# Out:
# 96.51

# %%
m2(front_files_data)
# Out:
# 1.16

# %%
m3(front_files_data)
# Out:
# 95.35

# %%
m4(front_files_data)
# Out:
# 0.0

# %%
m5(front_files_data)
# Out:
# Project test unit density:  100.0
#                                                  path test_success_density
# 0   sysarq/src/tests/Documents/Create/ConnectionEr...                100.0
# 1   sysarq/src/pages/components/Inputs/Abbreviatio...                100.0
# 2                                   sysarq/src/Api.js                100.0
# 3                                   sysarq/src/App.js                100.0
# 4                        sysarq/src/tests/App.test.js                100.0
# 5   sysarq/src/pages/FieldsRegister/BoxAbbreviatio...                100.0
# 6            sysarq/src/tests/BoxAbbreviation.test.js                100.0
# 7   sysarq/src/pages/components/Container/ChipsCon...                100.0
# 8   sysarq/src/pages/components/CommonSet/CommonSe...                100.0
# 9   sysarq/src/pages/Documents/Create/CreateAdmini...                100.0
# 10  sysarq/src/tests/Documents/Create/CreateAdmini...                100.0
# 11  sysarq/src/pages/Documents/Create/CreateArchiv...                100.0
# 12  sysarq/src/tests/Documents/Create/CreateArchiv...                100.0
# 13  sysarq/src/pages/FieldsRegister/CreateBoxAbbre...                100.0
# 14     sysarq/src/tests/CreateBoxAbbreviation.test.js                100.0
# 15  sysarq/src/pages/FieldsRegister/CreateDocument...                100.0
# 16     sysarq/src/tests/CreateDocumentSubject.test.js                100.0
# 17  sysarq/src/pages/FieldsRegister/CreateDocument...                100.0
# 18        sysarq/src/tests/CreateDocumentType.test.js                100.0
# 19  sysarq/src/pages/Documents/Create/CreateFreque...                100.0
# 20  sysarq/src/tests/Documents/Create/CreateFreque...                100.0
# 21  sysarq/src/pages/Documents/Create/CreateFreque...                100.0
# 22  sysarq/src/tests/Documents/Create/CreateFreque...                100.0
# 23     sysarq/src/pages/FieldsRegister/CreateShelf.js                100.0
# 24               sysarq/src/tests/CreateShelf.test.js                100.0
# 25     sysarq/src/pages/FieldsRegister/CreateUnity.js                100.0
# 26               sysarq/src/tests/CreateUnity.test.js                100.0
# 27                 sysarq/src/tests/DataTable.test.js                100.0
# 28  sysarq/src/tests/ConnectionErrors/DataTableCon...                100.0
# 29       sysarq/src/tests/Documents/Documents.test.js                100.0
# 30  sysarq/src/pages/components/Container/Document...                100.0
# 31  sysarq/src/pages/components/Actions/DocumentsC...                100.0
# 32  sysarq/src/pages/FieldsRegister/DocumentSubjec...                100.0
# 33           sysarq/src/tests/DocumentSubject.test.js                100.0
# 34  sysarq/src/tests/Documents/Create/ConnectionEr...                100.0
# 35    sysarq/src/pages/FieldsRegister/DocumentType.js                100.0
# 36              sysarq/src/tests/DocumentType.test.js                100.0
# 37  sysarq/src/tests/Documents/Create/ConnectionEr...                100.0
# 38  sysarq/src/pages/components/Inputs/DocumentTyp...                100.0
# 39  sysarq/src/pages/FieldsRegister/FieldsRegister.js                100.0
# 40            sysarq/src/tests/FieldsRegister.test.js                100.0
# 41            sysarq/src/pages/FieldsRegister/form.js                100.0
# 42      sysarq/src/pages/FieldsRegister/FrontCover.js                100.0
# 43                sysarq/src/tests/FrontCover.test.js                100.0
# 44                           sysarq/src/pages/Home.js                100.0
# 45                                sysarq/src/index.js                100.0
# 46                  sysarq/src/tests/support/index.js                100.0
# 47     sysarq/src/pages/components/DataTable/index.js                100.0
# 48  sysarq/src/pages/components/SpecialLabels/inde...                100.0
# 49  sysarq/src/pages/components/MenuCard/Documents...                100.0
# 50  sysarq/src/pages/components/MenuCard/Fields/in...                100.0
# 51        sysarq/src/pages/components/Footer/index.js                100.0
# 52       sysarq/src/pages/components/AddChip/index.js                100.0
# 53    sysarq/src/pages/components/PopUpAlert/index.js                100.0
# 54        sysarq/src/pages/components/Header/index.js                100.0
# 55                sysarq/src/pages/Documents/index.js                100.0
# 56                    sysarq/src/pages/Login/index.js                100.0
# 57                     sysarq/src/tests/index.test.js                100.0
# 58                 sysarq/src/tests/inputTest.test.js                100.0
# 59                     sysarq/src/tests/Login.test.js                100.0
# 60                  sysarq/src/tests/MenuCard.test.js                100.0
# 61   sysarq/src/pages/components/Inputs/NotesInput.js                100.0
# 62  sysarq/src/pages/components/Inputs/NumberInput.js                100.0
# 63  sysarq/src/pages/components/Inputs/NumberProce...                100.0
# 64                  sysarq/src/Routes/privateRoute.js                100.0
# 65  sysarq/src/tests/Documents/Create/ConnectionEr...                100.0
# 66    sysarq/src/pages/components/Inputs/RackInput.js                100.0
# 67  sysarq/src/pages/components/Inputs/ReceivedDat...                100.0
# 68  sysarq/src/pages/components/Inputs/ReferencePe...                100.0
# 69                      sysarq/src/reportWebVitals.js                100.0
# 70                         sysarq/src/pages/Search.js                100.0
# 71                    sysarq/src/tests/Search.test.js                100.0
# 72                     sysarq/src/pages/SearchList.js                100.0
# 73                sysarq/src/tests/SearchList.test.js                100.0
# 74  sysarq/src/pages/components/Inputs/SenderUnitI...                100.0
# 75                 sysarq/src/tests/support/server.js                100.0
# 76                           sysarq/src/setupTests.js                100.0
# 77           sysarq/src/pages/FieldsRegister/Shelf.js                100.0
# 78                     sysarq/src/tests/Shelf.test.js                100.0
# 79  sysarq/src/tests/Documents/Create/ConnectionEr...                100.0
# 80   sysarq/src/pages/components/Inputs/ShelfInput.js                100.0
# 81                              sysarq/src/support.js                100.0
# 82  sysarq/src/pages/components/DataTable/tablesHe...                100.0
# 83  sysarq/src/tests/Documents/Create/ConnectionEr...                100.0
# 84           sysarq/src/pages/FieldsRegister/Unity.js                100.0
# 85                     sysarq/src/tests/Unity.test.js                100.0

# %%
m6(front_files_data)
# Out:
# Project test unit density:  nan
# Empty DataFrame
# Columns: [path, fast_test]
# Index: []

# %% [markdown]
# #### ARCHIVES

# %%
m1(archives_files_data)
# Out:
# 31.58

# %%
m2(archives_files_data)
# Out:
# 26.32

# %%
m3(archives_files_data)
# Out:
# 100.0

# %%
m4(archives_files_data)
# Out:
# 0.0

# %%
m5(archives_files_data)
# Out:
# Project test unit density:  100.0
#                                        path test_success_density
# 0   archives_app/migrations/0001_initial.py                100.0
# 1                  archives_app/__init__.py                100.0
# 2       archives_app/migrations/__init__.py                100.0
# 3                       project/__init__.py                100.0
# 4                     archives_app/admin.py                100.0
# 5                      archives_app/apps.py                100.0
# 6                           project/asgi.py                100.0
# 7          archives_app/documents_models.py                100.0
# 8     archives_app/documents_serializers.py                100.0
# 9             archives_app/fields_models.py                100.0
# 10       archives_app/fields_serializers.py                100.0
# 11                                manage.py                100.0
# 12               archives_app/middleware.py                100.0
# 13                tests/middleware_tests.py                100.0
# 14                      project/settings.py                100.0
# 15                          project/urls.py                100.0
# 16                      tests/urls_tests.py                100.0
# 17                    archives_app/views.py                100.0
# 18                          project/wsgi.py                100.0

# %%
m6(archives_files_data)
# Out:
# Project test unit density:  nan
# Empty DataFrame
# Columns: [path, fast_test]
# Index: []

# %% [markdown]
# #### PROFILE

# %%
m1(profile_files_data)
# Out:
# 26.67

# %%
m2(profile_files_data)
# Out:
# 20.0

# %%
m3(profile_files_data)
# Out:
# 100.0

# %%
m4(profile_files_data)
# Out:
# 0.0

# %%
m5(profile_files_data)
# Out:
# Project test unit density:  100.0
#                                       path test_success_density
# 0   profile_app/migrations/0001_initial.py                100.0
# 1                  profile_app/__init__.py                100.0
# 2       profile_app/migrations/__init__.py                100.0
# 3                      project/__init__.py                100.0
# 4                     profile_app/admin.py                100.0
# 5                      profile_app/apps.py                100.0
# 6                          project/asgi.py                100.0
# 7                                manage.py                100.0
# 8                    profile_app/models.py                100.0
# 9               profile_app/serializers.py                100.0
# 10                     project/settings.py                100.0
# 11                         project/urls.py                100.0
# 12                     tests/urls_tests.py                100.0
# 13                    profile_app/views.py                100.0
# 14                         project/wsgi.py                100.0

# %%
m6(profile_files_data)
# Out:
# Project test unit density:  nan
# Empty DataFrame
# Columns: [path, fast_test]
# Index: []
